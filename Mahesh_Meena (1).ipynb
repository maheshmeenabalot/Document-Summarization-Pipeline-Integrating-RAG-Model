# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.38.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)

# %%
! pip install streamlit -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 17.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 19.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 37.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 8.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.7 MB/s eta 0:00:00

# %%
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 2.9 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1

# %%
# !pip install PyMuPDF
# Out:
# Collecting PyMuPDF
#   Downloading PyMuPDF-1.24.0-cp310-none-manylinux2014_x86_64.whl (3.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 13.7 MB/s eta 0:00:00
# Collecting PyMuPDFb==1.24.0 (from PyMuPDF)
#   Downloading PyMuPDFb-1.24.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (30.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.8/30.8 MB 36.6 MB/s eta 0:00:00
# Installing collected packages: PyMuPDFb, PyMuPDF
# Successfully installed PyMuPDF-1.24.0 PyMuPDFb-1.24.0

# %%
import streamlit as st
import fitz  # PyMuPDF

def read_pdf(file_path):
    text = ""
    with fitz.open(file_path) as pdf:
        for page in pdf:
            text += page.get_text()
    return text

# Read the text from the uploaded PDF file
file_path = "input_file.pdf"  # Assuming the file is already uploaded with this name
pdf_text = read_pdf("input_file.pdf")

# Display the text using Streamlit
# st.write("Text from PDF:")
# st.write(pdf_text)

print(pdf_text)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-ef18602dd389> in <cell line: 13>()
#      11 # Read the text from the uploaded PDF file
#      12 file_path = "input_file.pdf"  # Assuming the file is already uploaded with this name
# ---> 13 pdf_text = read_pdf("input_file.pdf")
#      14
#      15 # Display the text using Streamlit
#
# <ipython-input-5-ef18602dd389> in read_pdf(file_path)
#       4 def read_pdf(file_path):
#       5     text = ""
# ----> 6     with fitz.open(file_path) as pdf:
#       7         for page in pdf:
#       8             text += page.get_text()
#
# /usr/local/lib/python3.10/dist-packages/fitz/__init__.py in __init__(self, filename, stream, filetype, rect, width, height, fontsize)
#    2693                 if not os.path.exists(filename):
#    2694                     msg = f"no such file: '{filename}'"
# -> 2695                     raise FileNotFoundError(msg)
#    2696                 elif not os.path.isfile(filename):
#    2697                     msg = f"'{filename}' is no file"
#
# FileNotFoundError: no such file: 'input_file.pdf'

# %%
# %%writefile app.py

import streamlit as st
from transformers import pipeline
import fitz  # PyMuPDF

# Load your custom text summarization model
pipe = pipeline("summarization", model="Falconsai/text_summarization")

def read_pdf(file_path):
    text = ""
    with fitz.open(file_path) as pdf:
        for page in pdf:
            text += page.get_text()
    return text

def generate_summary(paragraph):
    curr_chunk = ""
    summaries = []

    # Generate summary
    for curr_word in paragraph:
        if len(curr_chunk) == 1024:
            summary = pipe(curr_chunk)
            summaries.append(summary[0]['summary_text'])
            curr_chunk = ""
        else:
            curr_chunk += curr_word

    final_summary = ' '.join(summaries)
    return final_summary

def main():
    st.title("Text Summarization App")
    st.write("Welcome to the Text Summarization App! Upload your PDF file below:")

    # File upload
    uploaded_file = st.file_uploader("Upload PDF", type=["pdf"])

    if uploaded_file is not None:
        # Read PDF file
        pdf_text = read_pdf(uploaded_file)

        # Display extracted text
        st.write("Text extracted from PDF:")
        st.write(pdf_text)

        if st.button("Summarize"):
            # Generate summary
            summary = generate_summary(pdf_text)
            st.write("Your summary:")
            st.write(summary)

if __name__ == "__main__":
    main()
# Out:
# Writing app.py

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 34.74.47.59

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to False.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.74.47.59:8501
#
# npx: installed 22 in 6.627s
# your url is: https://tiny-hounds-find.loca.lt
